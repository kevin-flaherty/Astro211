# %% [markdown]
# # Machine Learning
#
# ---
#
# ### Names: [name here]
#
# **Before you do anything else, go to *File -> Save As* and change the filename to include your name or initials. Make any requested edits to that copy.**
#
# This lab explores machine learning tasks as applied to astronomical data sets. Much of this is inspired by *Machine Learning for Physics and Astronomy* by Dr. Viviana Acquaviva. The article *Machine Learning in Astronomy: A Practical Overview* by Dalya Baron is another useful resource.

# %% [markdown]
# #### New Code:
#
# This lab will introduce a number of different pieces of code, including code that can:
#
# *   Apply a Decision Tree Classifier to a system
# *   Apply Principal Component Analysis to a system
# *   Apply a Gaussian Mixture Model to a system
# *   Apply Linear Regression to a system
#
# and methods that can test a model, including:
# *   Plot the confusion matrix for a classification scheme
# *   Calculate the $R^2$ value of a Linear Regression
# *   Calculate the accuracy score of a classification scheme
# *   Split out training and test sets from a data set
# *   Calculate the explained variance ratio for a PCA
#
# ---

# %%
# Import useful packages
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
#from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, ConfusionMatrixDisplay #, roc_curve
from sklearn.preprocessing import RobustScaler
#from sklearn.model_selection import cross_val_score

#!pip install git+http://github.com/astropy/astroquery.git#egg=astroquery
# First, suppress some warnings and import useful packages
import warnings
warnings.filterwarnings('ignore',module='astropy.io.votables.tree')
warnings.filterwarnings('ignore',message='.*unclosed..socket')

import astropy.units as u
#from astropy.coordinates import SkyCoord, ICRS
from astroquery.sdss import SDSS #package that allows queries of the SDSS database

# %% [markdown]
# *Machine Learning* refers to a class of algorithms that are designed to make informed, data-driven decisions. It is a very broad class, and includes many distinct methods, with seemingly little in common. At times it can seem like magic, especially when extended to artificial intelligence.
#
# Generally speaking, machine learning tools are used to do one of the following four things:
# * Recognize an instance of a certain type. For example, you have an image and would like to identify whether the object in the center is a galaxy, a star, a nebula, etc.
# * Predict some property or information on the basis of other information. For example, given a sequence of images of an object whose flux varies with time in some complicated way, predict the flux of the object next week/month/year so that you can plan observations of it.
# * Group together objects that are similar. For example, you are working with data from a new survey of the sky, and want to group together all of the galaxies in the images, all of the stars, and all of the nebula, and all of the interesting objects that don't fit into these categories. This can also be useful to find outliers (i.e., which objects fall into a group of one?)
# * Simplify the information contained in a complicated data. For example, you have measurements of the brightness of hundreds of millions of galaxies at hundreds of different wavelengths, and want to simplify the observations of each galaxy to a couple of key factors, so that you can see how these factors vary between different types of galaxies.

# %% [markdown]
# Machine learning in astronomy can be used to complement, or in place of, more detailed fitting of models that are informed by an understanding of the underlying physics. Each approach has its distinct advantages and disadvantages.
#
# |Machine Learning|Model Fitting|
# |---------|-------------------|
# |Data-driven (only as good as the data) | Intution or model-driven (only as good as the scientist) |
# |Usually generalizes poorly (model derived using some data can't be applied blindly to different data) | Generalizes well if the phyiscs is well understood |
# |Interpretation is possible but might be nontrivial | Easier to interpret|
# |Fast(er) | Might be computationally intensive|
# |More robust/accomodating of mixed and missing data | Dealing with heterogeneous data often a pain in the neck|
# |Allows serendipitous discoveries| Leads to loss of information if models are too simplistic|

# %% [markdown]
# This lab will introduce you to some algorithms in machine learning (hereafter ML), but it will just barely scratch the surface. Many online resources exist that describe the plethora of algorithms, many of which are collected in the `sklearn` python package, and as a result follow a very similar syntax.
#
# Instead we will focus on how to figure out if your machine learning algorithm has done something useful and accurate. It may be easy to run an ML algorithm, but our interest is in the scientific result, and hence we need to be careful that the ML algorithm hasn't led us astray, does not have some huge bias, etc. As you go through this lab, note when you see
#
# #### Test
#
# as this will be a sign of a way to verify a ML algorithm. This is not an exhaustive list, but is a start.

# %% [markdown]
# Let's start by loading in a dataset to play around with.

# %%
SDSS.timeout=120
query_string ='''select top 10000
  p.psfMag_u, p.psfMag_g, p.psfMag_r, p.psfMag_i, p.psfMag_z,
  sp.fehadop, sp.teffadop, sp.loggadop,
  spl.CaIIKside, spl.Halpha70side, spl.Hbetaside, spl.Hgammaside, spl.Hdeltaside, spl.CaII29side
from photoobjall p
join sppParams sp on sp.bestobjid = p.objid
join sppLines spl on spl.bestobjid = p.objid
where
  
  p.psfMagErr_u < 0.05 and
  p.psfMagErr_g < 0.05 and
  p.psfMagErr_r < 0.05 and
  p.psfMagErr_i < 0.05 and
  p.psfMagErr_z < 0.05 and

  p.psfMag_u-p.psfMag_g < 2.0 and
  p.psfMag_r-p.psfMag_i < 0.5 and
  p.psfMag_r-p.psfMag_i > -0.2 and
  p.psfMag_i-p.psfMag_z < 0.5 and

  sp.teffadopunc < 100 and
  sp.teffadopn > 3 and
  sp.loggadopunc between 0.01 and 0.1 and
  sp.loggadopn > 3 and
  sp.fehadopunc between 0.01 and 0.1 and
  sp.fehadopn > 3 and
  sp.snr > 30 and

  spl.CaIIKside > 0 and
  spl.CaIIKerr < 0.5 and
  spl.Halpha70side > 0 and
  spl.Halpha70err < 0.5 and
  spl.Hbetaside > 0 and
  spl.Hbetaerr < 0.5 and
  spl.CaII29side > 0 and
  spl.CaII29err < 0.5 and
  spl.Hdeltaside > 0 and
  spl.Hdeltaerr < 0.5 and 
  spl.Hgammaside > 0 and
  spl.Hgammaerr < 0.5

  

'''
data = SDSS.query_sql(query_string,verbose=False,timeout=600)
print(data)

data2 = {}
for key in data.keys():
    data2[key] = data[key]
df2 = pd.DataFrame(data2)  

### Scaling the data - See note about skipping this
#caler = RobustScaler()
#scaler.fit(df2)
#data2 = {}
#df2_scaled = scaler.transform(df2)
#for i,key in enumerate(data.keys()):
#    data2[key] = df2_scaled[:,i]
#df2 = pd.DataFrame(data2)
# Out:
# psfMag_u psfMag_g psfMag_r psfMag_i ... Hgammaside Hdeltaside CaII29side
# -------- -------- -------- -------- ... ---------- ---------- ----------
# 18.22762 17.19797 16.78441 16.61509 ...   1.586832    2.27846  0.9193059
# 17.06058 16.15749 15.76703 15.62506 ...   2.172885   2.491173    0.81837
# 17.06058 16.15749 15.76703 15.62506 ...   1.854718   2.431085  0.6359518
# 18.36561 17.15727 16.68746 16.50109 ...    1.17953    1.44663  0.3726786
# 18.36561 17.15727 16.68746 16.50109 ...  0.7647238   2.725884  0.4405977
# 17.22145 16.20605 15.82675 15.70448 ...   3.647644   4.222282   1.362695
# 17.22145 16.20605 15.82675 15.70448 ...   3.679126   4.465478  0.9704886
# 17.17523 16.07199 15.64886 15.51667 ...    1.66937   2.134904   1.304337
# 17.17523 16.07199 15.64886 15.51667 ...   1.847312    2.22464   1.312831
# 18.71254 17.49322 17.08677 16.93746 ...    1.80013  0.8969845  0.4002296
#      ...      ...      ...      ... ...        ...        ...        ...
# ...

# %% [markdown]
# Here we have used SQL to query the SDSS database, looking at stars studied as part of the SEGUE survey, which obtained spectra of over 300,000 stars in the Milky Way. From these spectra we can access the strength of various absorption lines (CaII K, Ca II IR, H $\alpha$, H $\beta$, H $\delta$, H $\gamma$), as well as stellar properties that were derived from the spectra (Metallicity (=[Fe/H]), effective temperature (=teff), the logarithm of the surface gravity (=logg)). I have also joined the SEQUE catalog with the SDSS photometry catalog to get *ugriz* photometry of each star.
#
#
# > #### NOTE:
# > Two very important initial steps, which I am skipping here for simplicity, are:
# > * *Cleaning your data*: This involves removing bad/missing data points
# > * *Normalizing the data*: Each parameter has a different scale, which can bias the algorithm. Normally we want to normalize the data (e.g., subtract the mean and divide by the standard deviation), but I have chosen to skip that to make it easier to interpret our results.
#
#
# The following code block plots the distribution of values for each of the parameters that we have collected.

# %%
def plot_data(data):
    '''This function takes in a pandas data frame and plots a histogram for each key in the data frame.'''
    plt.figure(figsize=(15,15))
    nplots = int(np.ceil(np.sqrt(len(data.columns))))

    for i,key in enumerate(data.columns):
        plt.subplot(nplots,nplots,i+1)
        plt.hist(data[key],50,histtype='step',color='k',density=True)
        plt.xlabel(key)


### Apply plot_data to our data
plot_data(df2)

# %% [markdown]
# ## Supervised Learning
#
# First, we will look at a *Supervised Learning* algorithm. This is an algorithm in which we have a *learning set* for which the target property (i.e., the temperature of the star) is known. An ML algorithm will use the learning set to infer a set of rules connecting the observed properties (e.g., photometry, line fluxes) to the target property.
#
# After training our algorithm on the data, we want some way to test how effectively it works. To do this we divide up our learning set into a *training set* and a *test set*. The ML algorithm will be trained on the training set, and then will be applied to the test set to see how well it does. Both the training and test set are subsets of the original learning set, and so each has the labels we need to train/verify the algorithm. Only after this set can the data be applied to data for which the labels do not exist.
#
# In the code block below, when we define the training and test set, we drop the column with the effective temperature because it would be cheating to use the temperature to predict the temperature. The block below uses the function `train_test_split` which automatically splits up the dataset into a training set and a test set.
#
# > **Q:** Look up the documentation online for the `train_test_split` function. What do `test_size` and `shuffle` do?
#
# **[Insert answer here]**

# %%
X_all = df2.drop(['teffadop'],axis=1)
y_all = (df2.teffadop<6000)

Xtrain_all, Xtest_all, ytrain_all, ytest_all = train_test_split(X_all, y_all, test_size=0.2,shuffle=True)

# %% [markdown]
# #### Test 1
# * Check that the feature space spanned by the learning set is the same as that of the population that we want to apply the model to.
#
# The first thing we need to do is make sure our test set and training set cover the same range of parameter space. If they do not (e.g., our training set only includes stars g<10, while our test set only includes stars with g>10) then our model will be biased and may not produce accurate results. Our ML algorithm will still run when applied to our test set, we just should not believe the results.
#
# > **Q:** Using the `plot_data` function defined above, examine the data across all of the parameters to see if the training set and test set cover the same range of parameter space. Do the training and test sets cover the same range of parameter space?
#
# **[Insert answer here]**

# %%
### Insert code here
plot_data(Xtrain_all)
plot_data(Xtest_all)

# %% [markdown]
# ### Classification
#
# *Roses are red\
# Violets are blue\
# This is a binary classifier\
# The outputs are only two.* - Viviana Acquaviva
#
# Lets assume that all stars with temperatures greater than 6000 K are hot, and all other stars are cold. How well can we predict whether or not a star is hot or cold based on its photometry, the strength of its absorption lines, and its Fe/H and log g?
#
# The code block below trains a particular ML algorithm (a Decision Tree) on the data set, and then uses that algorithm to predict the classification of the objects in the test set. Machine learning algorthms in the `sklearn` package follow this same general syntax of:
#
# ```python
# model = [Some ML algorithm]
# model.fit(Xtrain,ytrain)
# ypred = model.predict(Xtest)
# ```
#
# Where the first line defines the type of ML algorithm we are using, the second line trains the ML algorithm on our training set, and the third line predicts a set of values (in this case, whether or not a planet is habitable) for our test set.

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(Xtrain_all,ytrain_all)
ypred = model_dt.predict(Xtest_all)

# %% [markdown]
# #### Test 2
#
# The simplest metric for an classification algorithm is how accurately it predicts the classifications within the test set. To quantify this we can calculate an *accuracy score* which is the fraction of classifications that the algorithm gets correct.

# %%
print('Accuracy Score: ',accuracy_score(ytest_all,ypred))
# Out:
# Accuracy Score:  0.9155

# %% [markdown]
# #### Test 3
#
# Another way to look at this is with a *confusion matrix*. This is a matrix showing how the classifications break down, in terms of the number of objects that (1) are hot, and are predicted to be hot, (2) are cold, and are predicted to be cold, (3) are hot, but are predicted to be cold, (4) are cold, but are predicted to be hot.

# %%
cm = confusion_matrix(ytest_all,ypred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Hot Star','Cold Star'])
disp.plot()

# %% [markdown]
# Not bad! In order to talk in more detail about the results, we need to introduce some terminology.
#
# We have assigned "Cold" as "Negative". From this we can define four numbers: the amount of True Positives (TP), True Negatives (TN), False Positives (FP), and False Negatives (FN). In this convention, the second word is the classification assigned by the model, and the first word indicates whether or not the classification is true.
#
# In this language, our accuracy score is the total number of corret classifications over the total number: (TN+TP)/(TN+TP+FN+FP).
#
#
#
#
# *Precision:* (=purity) The fraction of correct positive classifications (=TP/(TP+FP)). Out of all the examples that have been classified as belonging to the positive class, how many of these actually belong to the positive class?
#
# *Recall:* (=completeness) The fraction of correctly identified positive examples (=TP/(TP+FN)). Out of the totality of objects that truly belong to the positive class, how many of them has our model captured?
#
# Maximizing either the precision or recall depends on the science question you are interested in.
#
# #### Test 4
# * Quantify precision and recall.
#
# > **Q:** What is the precision and recall of our ML algorithm?
#
# **[Insert answer here]**
#
#
# > **Q:** Suppose you were interested in studying cool stars, and wanted to pick out as many cool stars as possible. Would you favor high precision, or high recall? (Obviously we would like both, but lets assume you can only pick one)
#
# **[Insert answer here]**

# %% [markdown]
# ### Regression
#
# *Shall I compare thee to a gradient descent?\
# Probably not, that would be reaching a new low.*
#
# You may have looked at the above exercise and thought *Wouldn't it be better to predict the temperature directly, rather than splitting our sample into hot and cold stars?* In classification the result is a discrete property (e.g., this object is a galaxy/star/nebula/other), while for *regression* the result can be a continuous property (e.g., based on the BVRI photometry for a collection of stars, predict the I magnitude for stars for which we only have BVR magnitudes).
#
# The following code block uses a linear regression model. Note the similarity in syntax; we have changed the model, but the method for training the modeling, and predicting results, is the same.

# %%
from sklearn import linear_model


Xtrain_all, Xtest_all, ytrain_all, ytest_all = train_test_split(X_all, df2.teffadop, test_size=0.2,shuffle=True)

model_lr = linear_model.LinearRegression()
model_lr.fit(Xtrain_all,ytrain_all)

ypred = model_lr.predict(Xtest_all)

# %% [markdown]
# > **Q:** In the code block below create a plot of Predicted Temperature (`ypred`) vs Actual Temperature (`ytest_all`). Add labels to the axes, and add a line showing where the values are equal. How well does the algorithm predict the temperature?
#
# **[Insert answer here]**

# %%
### Insert code here

plt.plot(ypred,ytest_all,'.k')
plt.plot([ytest_all.min(),ytest_all.max()],[ytest_all.min(),ytest_all.max()],'--r')
plt.xlabel('Predicted temperature')
plt.ylabel('True temperature')
# Out:
# Text(0, 0.5, 'True temperature')

# %% [markdown]
# #### Test 5
#
# One way we can test linear regression is with the R$^2$ value, which is defined as:
#
# $R^2 = 1 - (\Sigma(y_{true}-y_{pred})^2)/(\Sigma(y_{true}-<y_{true}>)^2)$
#
# The closer the predicted values ($y_{pred}$) are to the true values ($y_{true}$), the closer the $R^2$ value is to 1.0. A value close to zero is a sign of a very poor prediction.
#
# > **Q:** The code block below calculates the $R^2$ value for our Linear Regression. How does it do?

# %%
print(model_lr.score(Xtest_all,ytest_all)) ### R^2 score for our model
# Out:
# 0.9544960153051815

# %% [markdown]
# ## Unsupervised Learning
#
# Sometimes we are interested in discovering patterns within our data, without the help of labeled examples.
#
# ### Dimensionality Reduction
#
# *There was once a girl from West Reading\
# Whose data were too big for keeping\
# So to keep them at bay\
# She did PCA\
# But they lost all their physical meaning* - Viviana Acquaviva
#
# First we will look at Dimensionality Reduction, which focuses on "simplifying" a data set. This can involve retaining the original information from a data, but only retaining the pieces that are most meaningful. Or the original data can be remapped into a different feature space, in which fewer components are needed to explain the data set.

# %% [markdown]
# With our stellar data set, you might suspect that many of the properties are correlated with each other (e.g., the strength of the H-alpha line is correlated with the strength of the H-beta line). With dimensionality reduction we hope to reduce the size of the data (e.g., instead of having measurements of 14 different properties for each star, we reduce this to 3), without losing any of the complexity contained in the original properties. This can help make the visualization of patterns or our exploration of the data easier, and it can be used as a pre-processing step before applying other models (e.g., before linear regression or classification).
#
#
#
# In practice, this starts with the same basic process as before:
# ```python
# model = [Some ML algorithm]
# model.fit(X,y)
# ```
#
# But now we can tranform the data into the principal components:
#
# ```python
# X_new = model.transform(X)
# ```
#
# Note that we no longer have a training and test set. This has the advantage of allowing us to use all of the data to train our ML algorithm, but we then lose one of our methods for testing the accuracy of our ML algorithm. In unsupervised learning, with no labels there is no "truth" that we can compare against. Instead we have to explore other ways of evaluating the ability of our ML algorithm.

# %%
### Here we use Principal Component Analysis, which breaks the data down into a number of orthogonal components.
### The input n_components controls the number of components used in the decomposition.

from sklearn import decomposition

X_all = df2
model_pca = decomposition.PCA(n_components=3)
model_pca.fit(X_all)


### This transforms our data based on the PCA
X_all_scaled = model_pca.transform(X_all)

# %% [markdown]
# #### Test 6
#
# After performing this tranformation, we want to check how well it captures our data. One metric is the *explained variance ratio*. This is the amount of spread in the data that is captured by each component of the PCA. Ideally the amount of spread would add up to 1.

# %%
print(model_pca.explained_variance_ratio_)
# Out:
# [9.99909882e-01 4.62587406e-05 2.26705658e-05]

# %% [markdown]
# > **Q:** How many terms are needed to capture 99% of the variance in the data?
#
# **[Insert answer here]**

# %% [markdown]
# #### Test 7
#
# We can examine how well our method deconstructs the data by reconstruction the original measurements from the smaller components, and examining the fractional difference between the original and reconstructed values.
#
# The following code block plots the fractional difference between the original and reconstructed measurements.
#
# > **Q:** How well does the dimensionality reduction perform? Look at the size of the fractional difference, any parameters, and values of parameters, for which the reconstruction does better or worse.

# %%
X_all_rec = model_pca.inverse_transform(X_all_scaled) ### This line reconstructs the orignal measurements from the deconstructed values.

plt.figure(figsize=(20,20))
nplots = int(np.ceil((X_all.shape[1])/2))
for i,key in enumerate(X_all.keys()):
    plt.subplot(nplots,nplots,i+1)
    plt.plot(X_all[key],(X_all_rec[:,i]-X_all[key])/X_all[key],'.k')
    plt.plot([X_all[key].min(),X_all[key].max()],[0,0],'--r')
    plt.xlabel('Actual '+key)
    plt.ylabel('Fractional Difference')

plt.figure(figsize=(20,20))
for i,key in enumerate(X_all.keys()):
    plt.subplot(nplots,nplots,i+1)
    plt.hist((X_all_rec[:,i]-X_all[key])/X_all[key],100,histtype='step',color='k',density=True)
    plt.xlabel('Fractional Difference')

# %% [markdown]
# ### Clustering
#
# With clustering we can highlight the similarities, and differences, in a data set. This helps with finding substantial groupings within our data. A classic example in astronomy is the classification of galaxies based on their appearance. Over 100 years ago the Hubble sequence was developed, in which galaxies were first divided into *elliptical galaxies*, which looked like smooth balls of stars, and *spiral galaxies*, which showed large spiral arms emanating out from the center of the galaxy. These are further divided into categories based on the shape of the elliptical galaxy (e.g., circular vs more elongated) or the properties of the spiral galaxy (e.g. relative brighness of the center vs the arms, the tightness of the arms).
#
# Many ML algorithms have attempted to recreate this division, either by using galaxies that have been labeled according to the Hubble sequence (i.e. supervised learning), or by asking a ML algorithm to find its own groupings within the data. [Say something about the conclusion of these studies... ]
#
# Clustering algorithms can not only find the main grouping within a data, but they are also useful in finding the outliers in a data set; after running a clustering algorithm, find the data points that do not fall into the main groupings, or that fall into a group that contains only one or two members.

# %% [markdown]
# In the block below we define a *Gaussian Mixture Model* which breaks down the data into a series of multi-dimensional Gaussians. Each of those Gaussians has a set of means and standard deviations for each input parameter (e.g., u magntiude, H-alpha flux).

# %%
### Here we will use a Gaussian Mixture Model, which breaks down the data into a collection of Gaussian components.
### The input n_components controls the number of Gaussians used when breaking down the data.

from sklearn import mixture
model_gmm = mixture.GaussianMixture(n_components=5,covariance_type='full')
model_gmm.fit(X_all)
# Out:
# GaussianMixture(n_components=5)

# %% [markdown]
# To run this model, we had to specify number of Gaussians to use when fiting to the data. This is an example of a *hyper-parameter*. A *hyper-parameter* sits one level of abstraction above the parameters used to fit the data (e.g. the means and standard deviations of the Gaussians). Another example of a hyper-parameter is the number of components of the PCA algorithm that you ran earlier. Optimizing a model can include interating over different values of the hyper-parameter(s) to see which provides a best fit.

# %% [markdown]
# The following block of code plots the distribution of values for each parameter (black historgram), along with the different components identified by the Gaussian Mixture Model (faint red dashed lines) and the sum of these components (green dotted line).
#
# #### Test 8
#
# > **Q:** Adjust the number of components in the Gaussian Mixture Model until the predicted distributions matches the actual distributions.

# %%
def gaussian(x,mu,sig):
    return (1/np.sqrt(2*np.pi*sig**2))*np.exp(-((x-mu)**2)/(2*sig**2))

nplots = int(np.ceil((X_all.shape[1])/2))
plt.figure(figsize=(20,20))
for i,key in enumerate(X_all.keys()):
    plt.subplot(nplots,nplots,i+1)
    plt.hist(X_all[key],100,histtype='step',color='k',density=True)
    ### full
    total = 0
    for mean,cov,weight in zip(model_gmm.means_[:,i],model_gmm.covariances_[:,i],model_gmm.weights_):
        plt.plot(np.linspace(X_all[key].min(),X_all[key].max(),100),weight*gaussian(np.linspace(X_all[key].min(),X_all[key].max(),100),mean,np.sqrt(cov[i])),'--r',alpha=.2)
        total += weight*gaussian(np.linspace(X_all[key].min(),X_all[key].max(),100),mean,np.sqrt(cov[i]))
    plt.plot(np.linspace(X_all[key].min(),X_all[key].max(),100),total,':g',lw=4)
    plt.xlabel(key)
    plt.ylabel('Probability Density')

# %% [markdown]
# ### Putting it all together
#
# A better way to predict the temperature of the stars might be to use their color (e.g., u-g, g-r, r-i) rather than the magnitudes, as the magnitudes will depend on the distance of the stars from us, the radii of the stars, etc.
#
# The SQL query below is identical to that from above, except it returns color instead of magnitude.
#
# > **Q:** Predict the temperature of the stars. Is using the color more effective than using the magnitudes directly?

# %%
SDSS.timeout=120
query_string ='''select top 10000
  p.psfMag_u-p.psfMag_g, p.psfMag_g-p.psfMag_r, p.psfMag_r-p.psfMag_i, p.psfMag_i-p.psfMag_z,
  sp.fehadop, sp.teffadop, sp.loggadop,
  spl.CaIIKside, spl.Halpha70side, spl.Hbetaside, spl.Hgammaside, spl.Hdeltaside, spl.CaII29side
from photoobjall p
join sppParams sp on sp.bestobjid = p.objid
join sppLines spl on spl.bestobjid = p.objid
where
  
  p.psfMagErr_u < 0.05 and
  p.psfMagErr_g < 0.05 and
  p.psfMagErr_r < 0.05 and
  p.psfMagErr_i < 0.05 and
  p.psfMagErr_z < 0.05 and

  p.psfMag_u-p.psfMag_g < 2.0 and
  p.psfMag_r-p.psfMag_i < 0.5 and
  p.psfMag_r-p.psfMag_i > -0.2 and
  p.psfMag_i-p.psfMag_z < 0.5 and

  sp.teffadopunc < 100 and
  sp.teffadopn > 3 and
  sp.loggadopunc between 0.01 and 0.1 and
  sp.loggadopn > 3 and
  sp.fehadopunc between 0.01 and 0.1 and
  sp.fehadopn > 3 and
  sp.snr > 30 and

  spl.CaIIKside > 0 and
  spl.CaIIKerr < 0.5 and
  spl.Halpha70side > 0 and
  spl.Halpha70err < 0.5 and
  spl.Hbetaside > 0 and
  spl.Hbetaerr < 0.5 and
  spl.CaII29side > 0 and
  spl.CaII29err < 0.5 and
  spl.Hdeltaside > 0 and
  spl.Hdeltaerr < 0.5 and 
  spl.Hgammaside > 0 and
  spl.Hgammaerr < 0.5

  

'''
data = SDSS.query_sql(query_string,verbose=False,timeout=600)
print(data)

data2 = {}
for key in data.keys():
    data2[key] = data[key]
df2 = pd.DataFrame(data2)  

### Scaling the data - Skip for now
#scaler = RobustScaler()
#scaler.fit(df2)
#data2 = {}
#df2_scaled = scaler.transform(df2)
#for i,key in enumerate(data.keys()):
#    #print(df2_scaled[:,i].shape,key)
#    data2[key] = df2_scaled[:,i]
#df2 = pd.DataFrame(data2)
# Out:
# Column1   Column2   Column3     Column4   ... Hgammaside Hdeltaside CaII29side
# -------- --------- ---------- ----------- ... ---------- ---------- ----------
# 1.065685 0.4014759  0.1133327  0.09802055 ...   1.939847   2.289974  0.3771449
# 1.102529 0.3719044  0.1555004  0.05065727 ...   2.602427   3.022869   1.233868
# 1.102494 0.4406595   0.114768  0.04799175 ...   1.721545   2.128415   1.685705
# 1.041086  0.376009  0.1148777  0.01033401 ...   2.627894   4.133331   1.752099
# 1.106026 0.4365425  0.1420937  0.07747459 ...   1.418604   2.234385   1.875706
#  1.27672 0.4710903   0.193922   0.0635643 ...  0.7572958  0.8848833   1.434673
# 1.096003 0.3788986  0.1515179  0.03058815 ...   1.748188  0.7716829   1.296083
# 1.096003 0.3788986  0.1515179  0.03058815 ...   1.815338   2.005954   1.812897
# 0.973917  0.263586  0.1356697  0.02207184 ...   2.475393   3.458409   1.836871
# 0.973917  0.263586  0.1356697  0.02207184 ...    4.03269   4.247396   1.920011
# ...

# %%
X_all = df2.drop(['teffadop'],axis=1)
Xtrain_all, Xtest_all, ytrain_all, ytest_all = train_test_split(X_all, df2.teffadop, test_size=0.2,shuffle=True)

model_lr_new = linear_model.LinearRegression()
model_lr_new.fit(Xtrain_all,ytrain_all)

ypred = model_lr_new.predict(Xtest_all)

plt.plot(ypred,ytest_all,'.k')
plt.plot([ytest_all.min(),ytest_all.max()],[ytest_all.min(),ytest_all.max()],'--r')
plt.xlabel('Predicted temperature')
plt.ylabel('True temperature')

print(model_lr_new.score(Xtest_all,ytest_all)) ### R^2 score for our model
# Out:
# 0.9535272642398097

# %% [markdown]
# Is there anything else you would like me to know, about class, labs, observing, or life in general?
#
# **Answer:**

# %% [markdown]
# #### To turn in this lab, either email me (kmf4) a copy of this notebook, or place your copy in Shared/Astro211_F25/MachineLearning folder in the Astro server.
