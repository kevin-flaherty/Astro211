# %% [markdown]
# ## Machine Learning - Follow Up
#
# **Before you do anything else, make a duplicate copy of this notebook, and update the name to include your name or initials. Make any requested edits to that copy.**
#
# ### Names: [Insert your names here]
#
# Complete the activities below before the start of lab. Feel free to refer back to your python notebook from last week.

# %% [markdown]
# ---
# #### *You are allowed to use AI on any portion of this notebook.*
#
# ---

# %% [markdown]
# ## 1
#
# For each item in the list below, list the broad categories of machine learning algorithms (e.g., classification, regression, dimensionality reduction, clustering) that could be applied:
#
# * Classifying galaxies using photometry.
# * Classifying galaxies using images.
# * Predicting the redshift of a galaxy based on multi-wavelength photometry.
# * Predicting the redshift of a galaxy based on its spectrum.
# * Find evidence of the Higgs boson in LHC data.
# * Using time-series photometry (i.e. photometry taken at different times) to identify and classify different types of variable events.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 2
#
# The following pseudo-code is designed to compare the sizes of elliptical and spiral galaxies, accounting for differences in brightness (e.g. for galaxies of comparable fluxes, which are bigger, spiral or elliptical galaxies?). It uses a data table that contains photometry at different wavelengths of various nearby galaxies. How can you update the code to test if the machine learning algorithm has worked properly?
#
# ```
# Read in the data table.
#
# Split the data set into elliptical galaxies and spiral galaxies.
# Define training set and test set for elliptical galaxies.
# Define training set and test set for spiral galaxies.
#
# Initialize LinearRegression algorithm.
# Apply LinearRegression to the training set of elliptical galaxies, predicting size from photometry.
# Apply LinearRegression to the training set of spiral galaxies, predicting size from photometry.
#
# Compare LinearRegression models to see which type of galaxy is bigger.
# ```

# %% [markdown]
# **Answer:**

# %% [markdown]
# #### To turn in this lab, either email me (kmf4) a copy of this notebook, or place your copy in the Shared/Astro211_F25/Lab1 folder in the Astro server.
